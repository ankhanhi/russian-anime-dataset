# %% [markdown]
# # Data processing script
#
# This script is intended for processing a dataset of anime information stored in the CSV file format. The dataset contains a variety of information about each anime title, such as the number of episodes, ratings, and release year.

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Set table printing options

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# ### Load data from file

# %%
data = pd.read_csv('D:/src/findanime/russian-anime-dataset/data/raw_data/findanime.csv', encoding="utf-8")

# %% [markdown]
# ### Create a copy of data for further processing

# %%
data_processed = data.copy()

# %% [markdown]
# ### Print the first 5 rows of data

# %%
data.head(5)
# Out:
#                                                Title  \
# 0  Ходячий замок (Howl's Moving Castle: Howl no U...
# 1  Унесённые призраками (Spirited Away: Sen to Ch...
# 2  Стальной Алхимик: Братство [ТВ-2] (FullMetal A...
# 3  Волейбол! 2 (Haikyuu!! Second Season: Haikyu!!...
# 4  В лесу мерцания светлячков (Into the Forest of...
#
#                          Short title  \
# 0                      Ходячий замок
# 1               Унесённые призраками
# 2  Стальной Алхимик: Братство [ТВ-2]
# 3                        Волейбол! 2
# 4         В лесу мерцания светлячков
#
#                                                 Href Translation  \
# 0              https://findanime.net/hodiachii_zamok  переведено
# 1         https://findanime.net/unesennye_prizrakami  переведено
# 2  https://findanime.net/stalnoi_alhimik__bratstv...  переведено
# 3           https://findanime.net/voleibol__2__A5678  переведено
# 4  https://findanime.net/into_the_forest_of_firef...  переведено
#
#                                          Description Count episodes  \
# 0  «Ходячий замок» — полнометражное аниме, выпуще...              1
# 1  Вместе с родителями маленькая Тихиро переезжае...              1
# 2  Нарушив главный запрет Алхимии и попытавшись в...             68
# 3  После участия в межшкольном чемпионате, волейб...             25
# 4  Маленькая девочка заблудилась в лесу, но вдруг...              1
#
#                                               Genres Rating Rating count  \
# 0  ['паропанк', 'фэнтези', 'сказка', 'приключения...    4.9          4.9
# 1  ['приключения', 'мистика', 'драма', 'семейный'...    4.9            5
# 2  ['война', 'драма', 'комедия', 'паропанк', 'фэн...    4.9          4.9
# 3    ['комедия', 'сёнэн', 'драма', 'спорт', 'школа']    4.9          4.9
# 4  ['мистика', 'сёдзё', 'романтика', 'трагедия', ...    4.8          4.7
#
#   World rating Characters rating Plot rating In_process Viewed In_favor  \
# 0          4.9               4.9         4.9        133  12924     9284
# 1          4.9                 5         4.9        110  12923     7541
# 2          4.9               4.9         4.9       1212   7230     3637
# 3          4.9               4.9         4.9       1351   6998     2747
# 4          4.8               4.9         4.8        212   9942     4697
#
#        Categories Year of release               Authors             Studios  \
# 0              []            2004  ['Диана Уинн Джонс']          ['Ghibli']
# 1              []            2001     ['Миядзаки Хаяо']          ['Ghibli']
# 2  ['TV сериалы']            2009    ['Аракава Хирому']           ['BONES']
# 3  ['TV сериалы']            2015  ['Фурудатэ Харуити']  ['Production I.G']
# 4              []            2011    ['Мидорикава Юки']     ['Brains Base']
#
#              Directors  Character designers  \
# 0    ['Миядзаки Хаяо']  ['Ямасита Акихико']
# 1    ['Миядзаки Хаяо']      ['Андо Масаси']
# 2     ['Ириэ Ясухиро']     ['Канно Хироки']
# 3  ['Мицунака Сусуму']  ['Кисида Такахиро']
# 4   ['Омори Такахиро']                   []
#
#                                           Characters  \
# 0                            ['Софи Хаттер', 'Хаул']
# 1    ['Тихиро Огино', 'Хаку (Унесённые призраками)']
# 2                                                 []
# 3  ['Кэйдзи Акаси', 'Хитока Яти', 'Кэндзи Футакут...
# 4                                                 []
#
#                                               Seiyuu  \
# 0                    ['Байсё Тиэко', 'Кимура Такуя']
# 1  ['Тамай Юми', 'Хиираги Руми', 'Ирино Мию', 'Ка...
# 2  ['Фудзивара Кэйдзи', 'Ёсино Хироюки (сэйю)', '...
# 3  ['Хосоя Ёсимаса', 'Морикубо Сётаро', 'Нака Хир...
# 4                     ['Утияма Коки', 'Сакура Аянэ']
#
#                                          Translators  \
# 0                                     ['ReaniMedia']
# 1                                                 []
# 2  ['Ancord', 'MiraiDuB', 'AlFair Studio', 'AniDu...
# 3  ['AniPlay.TV', 'AniStar', 'AniLibria.TV', 'AOS...
# 4  ['LE-Production', 'AniWave', 'Akari GROUP', 'A...
#
#                                                 Tags Popularity  \
# 0                                                 []          3
# 1                                                 []          3
# 2  ['Холодное оружие', 'Империи', 'Дружба', 'Учит...          3
# 3  ['Несколько ГГ', 'Дружба', 'Волейбол', 'Спорти...          3
# 4                                                 []          3
#
#                                              Reviews  \
# 0  ['\xa0 \xa0 "Ходячий замок Хаула", в другой тр...
# 1  [' Лет 10-12 назад (уж и не помню точно) зашла...
# 2  ['\xa0 \xa0Тема сравнения двух версий сериала ...
# 3  ['Вот и дошли руки написать отзыв о втором сез...
# 4  ['"И максимальной оценки будет мало..."Могу че...
#
#                                               Quotes  \
# 0  ['Прости меня, я такая капуша: ты ждал меня вс...
# 1  ['Если забудешь своё имя, то не сможешь вернут...
# 2  ['- Мне нравится эта вечная зима. Всё либо чер...
# 3                                                 []
# 4                                                 []
#
#                                        Similar anime  \
# 0  ['Навсикая из Долины Ветров', 'Унесённые призр...
# 1  ['Ходячий замок', 'Мой сосед Тоторо', 'Тетрадь...
# 2                        ['Стальной Алхимик [ТВ-1]']
# 3  ['Баскетбол Куроко [ТВ-1]', 'Синяя тюрьма: Блю...
# 4  ['Тетрадь дружбы Нацумэ', 'Сад изящных слов', ...
#
#                                            Image src
# 0  https://static.findanime.net/uploads/pics/00/1...
# 1  https://static.findanime.net/uploads/pics/00/1...
# 2  https://static.findanime.net/uploads/pics/00/1...
# 3  https://static.findanime.net/uploads/pics/00/4...
# 4  https://static.findanime.net/uploads/pics/00/1...

# %% [markdown]
# ### Summary statistics for numerical data

# %%
data.describe()
# Out:
#                                                     Title Short title  \
# count                                                7774        7774
# unique                                               7774        7760
# top     Ходячий замок (Howl's Moving Castle: Howl no U...    Мститель
# freq                                                    1           2
#
#                                          Href Translation  \
# count                                    7774        7774
# unique                                   7774           3
# top     https://findanime.net/hodiachii_zamok  переведено
# freq                                        1        6500
#
#                                               Description Count episodes  \
# count                                                7713           7774
# unique                                               7647            153
# top     Ригарт Эрроу — единственный лопух на всём чест...              1
# freq                                                    5           2099
#
#              Genres Rating Rating count World rating Characters rating  \
# count          7774   7774         7774         7774              7774
# unique         5924     42           44           38                44
# top     ['артхаус']    4.4            0            0                 0
# freq             79    740         2288         2294              2292
#
#        Plot rating In_process Viewed In_favor      Categories Year of release  \
# count         7774       7774   7774     7774            7774            7645
# unique          42        877   1814      866              93              71
# top            4.4          0      0        1  ['TV сериалы']            2021
# freq           740        510    510      647            3542             414
#
#        Authors Studios Directors Character designers Characters Seiyuu  \
# count     7774    7774      7774                7774       7774   7774
# unique    1761     739      1553                1075       1112   2831
# top         []      []        []                  []         []     []
# freq      2977    1310      1418                4845       6358   4787
#
#        Translators  Tags Popularity Reviews Quotes Similar anime  \
# count         7774  7774       7774    7774   7774          7774
# unique        3732   572          5    1773    135          5281
# top             []    []          0      []     []            []
# freq          1983  7139       3574    6002   7640           435
#
#                                                 Image src
# count                                                7774
# unique                                               7774
# top     https://static.findanime.net/uploads/pics/00/1...
# freq                                                    1

# %% [markdown]
# ### General information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7774 entries, 0 to 7773
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                7774 non-null   object
#  1   Short title          7774 non-null   object
#  2   Href                 7774 non-null   object
#  3   Translation          7774 non-null   object
#  4   Description          7713 non-null   object
#  5   Count episodes       7774 non-null   object
#  6   Genres               7774 non-null   object
#  7   Rating               7774 non-null   object
#  8   Rating count         7774 non-null   object
#  9   World rating         7774 non-null   object
#  10  Characters rating    7774 non-null   object
#  11  Plot rating          7774 non-null   object
#  12  In_process           7774 non-null   object
#  13  Viewed               7774 non-null   object
#  14  In_favor             7774 non-null   object
#  15  Categories           7774 non-null   object
#  16  Year of release      7645 non-null   object
#  17  Authors              7774 non-null   object
#  18  Studios              7774 non-null   object
#  19  Directors            7774 non-null   object
#  20  Character designers  7774 non-null   object
#  21  Characters           7774 non-null   object
#  22  Seiyuu               7774 non-null   object
#  23  Translators          7774 non-null   object
#  24  Tags                 7774 non-null   object
#  25  Popularity           7774 non-null   object
#  26  Reviews              7774 non-null   object
#  27  Quotes               7774 non-null   object
#  28  Similar anime        7774 non-null   object
#  29  Image src            7774 non-null   object
# dtypes: object(30)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Convert selected columns to numerical format

# %%
columns_to_numeric = [
    "Count episodes",
    "Rating",
    "Rating count",
    "World rating",
    "Characters rating",
    "Plot rating",
    "Characters rating",
    "In_process",
    "Viewed",
    "In_favor",
    "Year of release",
    "Popularity"
]
for column in columns_to_numeric:
    data_processed[column] = pd.to_numeric(data[column], errors="coerce")

# %% [markdown]
# ### Print updated information about data

# %%
data_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7774 entries, 0 to 7773
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                7774 non-null   object
#  1   Short title          7774 non-null   object
#  2   Href                 7774 non-null   object
#  3   Translation          7774 non-null   object
#  4   Description          7713 non-null   object
#  5   Count episodes       7773 non-null   float64
#  6   Genres               7774 non-null   object
#  7   Rating               7773 non-null   float64
#  8   Rating count         7773 non-null   float64
#  9   World rating         7773 non-null   float64
#  10  Characters rating    7773 non-null   float64
#  11  Plot rating          7773 non-null   float64
#  12  In_process           7773 non-null   float64
#  13  Viewed               7773 non-null   float64
#  14  In_favor             7773 non-null   float64
#  15  Categories           7774 non-null   object
#  16  Year of release      7644 non-null   float64
#  17  Authors              7774 non-null   object
#  18  Studios              7774 non-null   object
#  19  Directors            7774 non-null   object
#  20  Character designers  7774 non-null   object
#  21  Characters           7774 non-null   object
#  22  Seiyuu               7774 non-null   object
#  23  Translators          7774 non-null   object
#  24  Tags                 7774 non-null   object
#  25  Popularity           7773 non-null   float64
#  26  Reviews              7774 non-null   object
#  27  Quotes               7774 non-null   object
#  28  Similar anime        7774 non-null   object
#  29  Image src            7774 non-null   object
# dtypes: float64(11), object(19)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Save processed data to a new file

# %%
data_processed.to_csv("D:/src/findanime/russian-anime-dataset/data/processed_data/processed_findanime.csv")
